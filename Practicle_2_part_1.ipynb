# %% [markdown]
# <a href="https://colab.research.google.com/github/bitphonix/RL_21CSU437/blob/main/Practicle_2_part_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np

# %%
np.random.seed(1)

# %%
x = np.random.randint(0,50,1000)

# %%
print(x)
# Out:
# [37 43 12  8  9 11  5 15  0 16  1 12  7 45  6 25 20 37 18 20 11 42 28 29
#  14  4 23 23 41 49 30 32 22 13 41  9  7 22  1  0 17  8 24 13 47 42  8 30
#   7  3  6 21 49  3  4 24 49 43 12 26 16 45 41 18 15  0  4 25 47 34 23  7
#  26 25 40 22  9  3 39 23 36 27 37 19 38  8 32 34 10 23 15 47 23 25  7 28
#  10 46 32 24 23  1 49 13  3  0 13  6 21  6  2 12 27 21 11  7 13  8 11 12
#  43 20 30 36 39  7 45  4 48 18 32 13 10 23 17  7 24 10 28 20 32 12  1 30
#  41 24 18 33  2 44 28 39 34 10 32 41 18 22  6  2  7 39 48 15  5 17 42 20
#  48 22 37 13 49 33 20 10 32 25 21 39 32 19 25 49 14 13 20 43  6 13 15 24
#   9  2  7  5 36 37 21 40 13 27 49 49 47 13 40 14 45 23 16 28 42 45  3  2
#  14 46  0 29 11 35 29 33  2 20 19 48 32 28 18 31 28 30 10  8 45 35 32  8
#  20 13 15 41  0 44 19 24 49 42 20 44 15 30 27 14 19 26 43 22  7 35 47 46
#  34 36 36 32 19  3 24 19 37 30 38 47 39  5 15 49 23 32 42 10  2 24 34 30
#  17  4  0 14 17 39 35 17 28 22 38 41 10 13  6 25 38 48 48 44 41  0 22 16
# ...

# %%
y = x + np.random.normal(0,10,1000)
print(y)
# Out:
# [ 3.07313535e+01  7.57056570e+01  8.92959400e+00  4.15251149e+00
#   9.15189145e+00  2.87380256e+00 -2.87802052e+00  1.85785176e+00
#   1.98609381e+00  1.32929437e+01  3.81247183e+00 -5.40207435e-01
#   8.23125049e+00  3.13040021e+01 -6.74182464e-01  2.95771649e+01
#   5.37879784e+00  3.96358548e+01  2.60409543e+01  2.93496704e+01
#   1.35647913e+01  3.97081192e+01  7.18361352e+00  4.16696681e+01
#   2.20510449e+01  1.36030643e+01  2.73494945e+01  2.98021216e+01
#   5.96888402e+01  5.05070528e+01  2.43134192e+01  4.47493789e+01
#   2.95073347e+01  2.10973852e+01  2.66189513e+01  2.55905261e+01
#   1.01107257e+01  2.41571449e+01 -3.74747842e+00 -3.26341235e+00
#   9.89883481e+00 -2.03677010e+00  2.51424793e+01  2.31375566e+01
#   3.97996531e+01  3.77534355e+01  1.62006883e+01  1.48867710e+01
#   2.24892855e+00 -1.65950744e+01  1.85764523e+01  1.88581749e+01
#   3.03029112e+01 -5.92459222e+00 -6.95967165e+00  3.08851267e+01
# ...

# %%
import matplotlib
import matplotlib.pyplot as plt
# %matplotlib inline
matplotlib.style.use('ggplot')

plt.scatter(x,y)
plt.show()

# %% [markdown]
# when x and y both is increasing then there is positive corelation
# when x and y both is decreasing then there is positive corelation
# when x is inc/dec or y is inc/dec then there is negative corelation

# %%
np.corrcoef(x,y)
# Out:
# array([[1.        , 0.81250806],
#        [0.81250806, 1.        ]])

# %%
z = 100 - x

# %%
np.corrcoef(x,z)
# Out:
# array([[ 1., -1.],
#        [-1.,  1.]])

# %%
import matplotlib
import matplotlib.pyplot as plt
# %matplotlib inline
matplotlib.style.use('ggplot')

plt.scatter(x,z)
plt.show()

# %%
x = np.random.randint(0,50,100)
y = np.random.randint(0,50,100)
np.corrcoef(x,y)
# Out:
# array([[1.        , 0.12433307],
#        [0.12433307, 1.        ]])

# %%
import pandas as pd

df = pd.DataFrame({'a': np.random.randint(0,50,1000)})
df['b'] = df['a'] + np.random.normal(0,10,1000)
df['c'] = 100 - df['a'] + np.random.normal(0,5,1000)
df['d'] = np.random.randint(0,50,1000)

# %%
df.corr()
# Out:
#           a         b         c         d
# a  1.000000  0.822721 -0.944006  0.014391
# b  0.822721  1.000000 -0.770940  0.005309
# c -0.944006 -0.770940  1.000000 -0.028894
# d  0.014391  0.005309 -0.028894  1.000000

# %%
pd.plotting.scatter_matrix(df,figsize = (6,6))
plt.show()

# %%
plt.matshow(df.corr())
plt.xticks(range(len(df.columns)), df.columns)
plt.yticks(range(len(df.columns)), df.columns)
plt.colorbar()
plt.show()
